# %% [markdown]
# <a href="https://colab.research.google.com/github/yejin0455/sesac-ML/blob/main/D01_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
plt.plot(np.random.normal(0, 1.3, 100))

# %%
plt.plot(np.random.chisquare(1, 100))
